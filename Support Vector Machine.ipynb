# %% [markdown]
# # SVM classifier
# Support Vector Machines also called as SVM are one of the strongest Machine learning algorithm used for various purposes.

# %%
# We will be using a data set in which are aim to classify the label as male or female
# For more assistance you can checkout this page https://www.kaggle.com/nirajvermafcb/support-vector-machine-detail-analysis

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
# Visualizing th data
data = pd.read_csv("C:/Users/karti/Downloads/voice/voice.csv")
data.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# ...

# %%
# Checking for null values
data.isnull().any()
# Out:
# meanfreq    False
# sd          False
# median      False
# Q25         False
# Q75         False
# IQR         False
# skew        False
# kurt        False
# sp.ent      False
# sfm         False
# mode        False
# centroid    False
# meanfun     False
# minfun      False
# maxfun      False
# meandom     False
# mindom      False
# maxdom      False
# dfrange     False
# modindx     False
# label       False
# dtype: bool

# %%
# shuffling the dataset
import random
shuffle_dataset = []
for num in range(3168):
    shuffle_dataset.append(num)
random.shuffle(shuffle_dataset)

# %%
data = data.reindex(index = shuffle_dataset)

# %%
## Converting the data into 0 or 1, Just like one hot vectorizing the columns.

#data_label = data["label"]
data_label = pd.get_dummies(data.label)
data_label
# Out:
#       female  male
# 825        0     1
# 2777       1     0
# 1513       0     1
# 1583       0     1
# 2254       1     0
# ...      ...   ...
# 367        0     1
# 215        0     1
# 2830       1     0
# 72         0     1
# 2161       1     0
#
# [3168 rows x 2 columns]

# %%
data_label= data_label.drop(['male'], axis = 'columns')
data_label.rename(columns = {'female' : 'Gender'}, inplace = True)
data_label
# Out:
#       Gender
# 825        0
# 2777       1
# 1513       0
# 1583       0
# 2254       1
# ...      ...
# 367        0
# 215        0
# 2830       1
# 72         0
# 2161       1
#
# [3168 rows x 1 columns]

# %%
## Merging the dataset and again viewing it.

#data = data.drop(axis=1, columns = 'label', inplace = True)
#dataset=data.iloc[:, :-1]
dataset = data.drop(['label'], axis = 'columns')
dataset.rename(columns = {'sp.ent' : 'spent'}, inplace = True)

# %%
dataset
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR      skew  \
# 825   0.183981  0.056717  0.198841  0.141578  0.219130  0.077552  2.013467
# 2777  0.193523  0.038389  0.200042  0.165188  0.218787  0.053598  1.752535
# 1513  0.141566  0.076678  0.126486  0.100935  0.207994  0.107059  3.578447
# 1583  0.158781  0.059852  0.147013  0.107879  0.216797  0.108918  3.648593
# 2254  0.114828  0.084428  0.088618  0.044042  0.179905  0.135863  1.021112
# ...        ...       ...       ...       ...       ...       ...       ...
# 367   0.126735  0.083493  0.112816  0.055275  0.211737  0.156462  2.368228
# 215   0.173168  0.068850  0.192800  0.119733  0.230133  0.110400  1.191048
# 2830  0.233098  0.036174  0.238131  0.225421  0.249720  0.024299  3.166333
# 72    0.167083  0.064426  0.181705  0.107563  0.220742  0.113180  1.870944
# 2161  0.186823  0.035518  0.188381  0.174591  0.204741  0.030150  2.467077
#
# ...

# %%
Y = np.array(data_label['Gender'])
Y
# Out:
# array([0, 1, 0, ..., 1, 0, 1], dtype=uint8)

# %%
# Standardisation of the code. It means mean will be zero (0) and standard deviation of one (1). 

sc = StandardScaler()
X = sc.fit_transform(dataset)
X
# Out:
# array([[ 0.10277776, -0.0245762 ,  0.36363963, ...,  0.10418272,
#          0.11251518, -0.07911755],
#        [ 0.42177995, -1.12534102,  0.3966827 , ...,  1.16934181,
#          1.17801242, -0.62823479],
#        [-1.31517446,  1.17429399, -1.62662549, ..., -1.31602941,
#         -1.30370825, -0.18455232],
#        ...,
#        [ 1.7447606 , -1.25838182,  1.44439612, ...,  0.80319337,
#          0.75181353, -0.68427681],
#        [-0.46212359,  0.43843096, -0.10770527, ...,  0.04426752,
#         -0.00291369, -1.27104494],
#        [ 0.19779968, -1.29781358,  0.07591811, ...,  0.49252197,
#          0.50541729, -0.11601019]])

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

# %%
#Import svm model
from sklearn import svm
from sklearn import metrics

#Create a svm Classifier
model = svm.SVC(C= 1, kernel='rbf', gamma = 0.05)

#Train the model using the training sets
model.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = model.predict(X_test)

print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score:
# 0.9842271293375394

# %%
# Precision and recall value can be found by the following code --------->

print("Precision:",metrics.precision_score(y_test, y_pred))

print("Recall:",metrics.recall_score(y_test, y_pred))
# Out:
# Precision: 0.9838709677419355
# Recall: 0.9838709677419355

# %%
F1 = (2* metrics.precision_score(y_test, y_pred) * metrics.recall_score(y_test, y_pred)) / (metrics.precision_score(y_test, y_pred) + metrics.recall_score(y_test, y_pred))
print("F1 score is :", F1)
# Out:
# F1 score is : 0.9838709677419355
